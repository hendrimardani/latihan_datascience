# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('sentiment labelled sentences/yelp_labelled.txt', names=['kalimat', 'label'], sep='\t')
data
# Out:
#                                                kalimat  label
# 0                             Wow... Loved this place.      1
# 1                                   Crust is not good.      0
# 2            Not tasty and the texture was just nasty.      0
# 3    Stopped by during the late May bank holiday of...      1
# 4    The selection on the menu was great and so wer...      1
# ..                                                 ...    ...
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0
#
# [1000 rows x 2 columns]

# %%
X = data['kalimat'].values
y = data['label'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
tokenizer = Tokenizer(num_words=250, oov_token='x')
tokenizer.fit_on_texts(X_train) 
tokenizer.fit_on_texts(X_test)

    
kalimat_train = tokenizer.texts_to_sequences(X_train)
kalimat_test = tokenizer.texts_to_sequences(X_test)

pading_train = pad_sequences(kalimat_train) 
pading_test = pad_sequences(kalimat_test)

# %%
model = Sequential([
        layers.Embedding(250, 16), # input_length adalah panjang kalimat
        layers.GlobalAveragePooling1D(), # Sama seperti fungsi Flatten()
        layers.Dense(24, activation='relu'),
        layers.Dropout(0.4),
        layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(loss='binary_crossentropy',  
              optimizer='adam',
              metrics=['accuracy'])

# %%
history = model.fit(pading_train, y_train, epochs=30, 
                    validation_data=(pading_test, y_test), verbose=2)
# Out:
# Epoch 1/30
# 25/25 - 0s - loss: 0.6933 - accuracy: 0.4988 - val_loss: 0.6927 - val_accuracy: 0.4900 - 330ms/epoch - 13ms/step
# Epoch 2/30
# 25/25 - 0s - loss: 0.6919 - accuracy: 0.5175 - val_loss: 0.6911 - val_accuracy: 0.5800 - 39ms/epoch - 2ms/step
# Epoch 3/30
# 25/25 - 0s - loss: 0.6900 - accuracy: 0.5925 - val_loss: 0.6886 - val_accuracy: 0.6500 - 40ms/epoch - 2ms/step
# Epoch 4/30
# 25/25 - 0s - loss: 0.6868 - accuracy: 0.6400 - val_loss: 0.6859 - val_accuracy: 0.6750 - 40ms/epoch - 2ms/step
# Epoch 5/30
# 25/25 - 0s - loss: 0.6822 - accuracy: 0.6475 - val_loss: 0.6807 - val_accuracy: 0.6500 - 39ms/epoch - 2ms/step
# Epoch 6/30
# 25/25 - 0s - loss: 0.6756 - accuracy: 0.6837 - val_loss: 0.6742 - val_accuracy: 0.6500 - 39ms/epoch - 2ms/step
# Epoch 7/30
# 25/25 - 0s - loss: 0.6689 - accuracy: 0.6700 - val_loss: 0.6658 - val_accuracy: 0.7100 - 41ms/epoch - 2ms/step
# Epoch 8/30
# 25/25 - 0s - loss: 0.6584 - accuracy: 0.6762 - val_loss: 0.6554 - val_accuracy: 0.6750 - 40ms/epoch - 2ms/step
# Epoch 9/30
# 25/25 - 0s - loss: 0.6467 - accuracy: 0.7000 - val_loss: 0.6430 - val_accuracy: 0.6950 - 39ms/epoch - 2ms/step
# Epoch 10/30
# 25/25 - 0s - loss: 0.6240 - accuracy: 0.7500 - val_loss: 0.6289 - val_accuracy: 0.7300 - 38ms/epoch - 2ms/step
# Epoch 11/30
# 25/25 - 0s - loss: 0.6047 - accuracy: 0.7475 - val_loss: 0.6134 - val_accuracy: 0.6850 - 41ms/epoch - 2ms/step
# Epoch 12/30
# 25/25 - 0s - loss: 0.5800 - accuracy: 0.7663 - val_loss: 0.5945 - val_accuracy: 0.7650 - 38ms/epoch - 2ms/step
# Epoch 13/30
# 25/25 - 0s - loss: 0.5544 - accuracy: 0.7900 - val_loss: 0.5758 - val_accuracy: 0.7700 - 38ms/epoch - 2ms/step
# Epoch 14/30
# 25/25 - 0s - loss: 0.5376 - accuracy: 0.8037 - val_loss: 0.5600 - val_accuracy: 0.7200 - 38ms/epoch - 2ms/step
# Epoch 15/30
# 25/25 - 0s - loss: 0.5049 - accuracy: 0.8238 - val_loss: 0.5431 - val_accuracy: 0.7650 - 40ms/epoch - 2ms/step
# Epoch 16/30
# 25/25 - 0s - loss: 0.4960 - accuracy: 0.8213 - val_loss: 0.5308 - val_accuracy: 0.7600 - 37ms/epoch - 1ms/step
# Epoch 17/30
# 25/25 - 0s - loss: 0.4659 - accuracy: 0.8275 - val_loss: 0.5172 - val_accuracy: 0.7550 - 40ms/epoch - 2ms/step
# Epoch 18/30
# 25/25 - 0s - loss: 0.4481 - accuracy: 0.8225 - val_loss: 0.5090 - val_accuracy: 0.7800 - 39ms/epoch - 2ms/step
# Epoch 19/30
# 25/25 - 0s - loss: 0.4281 - accuracy: 0.8500 - val_loss: 0.5023 - val_accuracy: 0.7600 - 39ms/epoch - 2ms/step
# Epoch 20/30
# 25/25 - 0s - loss: 0.4089 - accuracy: 0.8475 - val_loss: 0.5005 - val_accuracy: 0.7650 - 41ms/epoch - 2ms/step
# Epoch 21/30
# 25/25 - 0s - loss: 0.3944 - accuracy: 0.8612 - val_loss: 0.4901 - val_accuracy: 0.7700 - 40ms/epoch - 2ms/step
# Epoch 22/30
# 25/25 - 0s - loss: 0.3751 - accuracy: 0.8500 - val_loss: 0.4934 - val_accuracy: 0.7650 - 40ms/epoch - 2ms/step
# Epoch 23/30
# 25/25 - 0s - loss: 0.3749 - accuracy: 0.8600 - val_loss: 0.4850 - val_accuracy: 0.7650 - 38ms/epoch - 2ms/step
# Epoch 24/30
# 25/25 - 0s - loss: 0.3617 - accuracy: 0.8625 - val_loss: 0.4843 - val_accuracy: 0.7900 - 39ms/epoch - 2ms/step
# Epoch 25/30
# 25/25 - 0s - loss: 0.3565 - accuracy: 0.8650 - val_loss: 0.4842 - val_accuracy: 0.7600 - 38ms/epoch - 2ms/step
# Epoch 26/30
# 25/25 - 0s - loss: 0.3427 - accuracy: 0.8625 - val_loss: 0.4838 - val_accuracy: 0.7850 - 41ms/epoch - 2ms/step
# Epoch 27/30
# 25/25 - 0s - loss: 0.3326 - accuracy: 0.8625 - val_loss: 0.4939 - val_accuracy: 0.7650 - 37ms/epoch - 1ms/step
# Epoch 28/30
# 25/25 - 0s - loss: 0.3178 - accuracy: 0.8737 - val_loss: 0.4847 - val_accuracy: 0.7700 - 38ms/epoch - 2ms/step
# Epoch 29/30
# 25/25 - 0s - loss: 0.3154 - accuracy: 0.8838 - val_loss: 0.4927 - val_accuracy: 0.7450 - 37ms/epoch - 1ms/step
# Epoch 30/30
# 25/25 - 0s - loss: 0.3180 - accuracy: 0.8813 - val_loss: 0.4914 - val_accuracy: 0.7700 - 39ms/epoch - 2ms/step

# %%
# INPUT
teks = [
    "good"
] 

tokenizer.fit_on_texts(teks)
kalimat_teks = tokenizer.texts_to_sequences(teks)
pading_teks = pad_sequences(kalimat_teks) 


y_pred = model.predict(pading_teks)
y_pred

# Membuat bil Int dari Dec
bulat = np.round(y_pred).reshape(1,-1)
y_pred = np.round(bulat)
y_pred
# Out:
# 1/1 [==============================] - 0s 34ms/step
# array([[1.]], dtype=float32)

# %%
# a = y_pred.flatten()
# b = y_test.flatten()

# data = {
#     "y_test" : b,
#     "y_pred" : a
# }
# pd.DataFrame(data)

# %%
data_baru = data = pd.read_csv('sentiment labelled sentences/yelp_labelled.txt', \
                               names=['kalimat', 'label'], sep='\t')
data_baru

# %%
data_baru[(data_baru["label"] == 1)].iloc[20:40]
# Out:
#                                               kalimat  label
# 40                       The shrimp tender and moist.      1
# 43  On a positive note, our server was very attent...      1
# 45  The only thing I did like was the prime rib an...      1
# 47        The burger is good beef, cooked just right.      1
# 48  If you want a sandwich just go to any Firehous...      1
# 49  My side Greek salad with the Greek dressing wa...      1
# 50  We ordered the duck rare and it was pink and t...      1
# 51  He came running after us when he realized my h...      1
# 52                        Their chow mein is so good!      1
# 54                              The portion was huge!      1
# 55  Loved it...friendly servers, great food, wonde...      1
# 58  The salad had just the right amount of sauce t...      1
# 61  This place receives stars for their APPETIZERS!!!      1
# 62      The cocktails are all handmade and delicious.      1
# 63                We'd definitely go back here again.      1
# 64                We are so glad we found this place.      1
# 65  Great food and service, huge portions and they...      1
# 66                Always a great time at Dos Gringos!      1
# 67  Update.....went back for a second time and it ...      1
# 69                     A great way to finish a great.      1
